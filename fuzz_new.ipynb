# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# Define the universe of discourse
username = ctrl.Antecedent(np.arange(0, 6, 1), 'username')
password = ctrl.Antecedent(np.arange(0, 6, 1), 'password')
email = ctrl.Antecedent(np.arange(0, 6, 1), 'email')
phone_number = ctrl.Antecedent(np.arange(0, 6, 1), 'phone_number')
aadhaar = ctrl.Antecedent(np.arange(0, 6, 1), 'aadhaar')  # New input
pan = ctrl.Antecedent(np.arange(0, 6, 1), 'pan')  # New input
sensitivity = ctrl.Consequent(np.arange(0, 11, 1), 'sensitivity')

# Define the membership functions to cover wide range of cases 
username.automf(5)
password.automf(5)
email.automf(5)
phone_number.automf(5)
aadhaar.automf(5)
pan.automf(5)
sensitivity.automf(5)

rule1 = ctrl.Rule(username['poor'] | password['poor'] | email['poor'] | phone_number['poor'] | aadhaar['poor'] | pan['poor'], sensitivity['poor'])
rule2 = ctrl.Rule(username['mediocre'] | password['mediocre'] | email['mediocre'] | phone_number['mediocre'] | aadhaar['mediocre'] | pan['mediocre'], sensitivity['mediocre'])
rule3 = ctrl.Rule(username['average'] | password['average'] | email['average'] | phone_number['average'] | aadhaar['average'] | pan['average'], sensitivity['average'])
rule4 = ctrl.Rule(username['decent'] | password['decent'] | email['decent'] | phone_number['decent'] | aadhaar['decent'] | pan['decent'], sensitivity['decent'])
rule5 = ctrl.Rule(username['good'] | password['good'] | email['good'] | phone_number['good'] | aadhaar['good'] | pan['good'], sensitivity['good'])
rule6 = ctrl.Rule(username['poor'] | password['poor'] | email['poor'] | phone_number['poor'] | aadhaar['poor'] | pan['poor'], sensitivity['poor'])
rule7 = ctrl.Rule(username['mediocre'] | password['mediocre'] | email['mediocre'] | phone_number['mediocre'] | aadhaar['mediocre'] | pan['mediocre'], sensitivity['mediocre'])
rule8 = ctrl.Rule(username['average'] | password['average'] | email['average'] | phone_number['average'] | aadhaar['average'] | pan['average'], sensitivity['average'])
rule9 = ctrl.Rule(username['decent'] | password['decent'] | email['decent'] | phone_number['decent'] | aadhaar['decent'] | pan['decent'], sensitivity['decent'])
rule10 = ctrl.Rule(username['good'] | password['good'] | email['good'] | phone_number['good'] | aadhaar['good'] | pan['good'], sensitivity['good'])
rule11 = ctrl.Rule(username['poor'] | password['poor'] | email['poor'] | phone_number['poor'] | aadhaar['poor'] | pan['poor'], sensitivity['poor'])
rule12 = ctrl.Rule(username['mediocre'] | password['mediocre'] | email['mediocre'] | phone_number['mediocre'] | aadhaar['mediocre'] | pan['mediocre'], sensitivity['mediocre'])
rule13 = ctrl.Rule(username['average'] | password['average'] | email['average'] | phone_number['average'] | aadhaar['average'] | pan['average'], sensitivity['average'])
rule14 = ctrl.Rule(username['decent'] | password['decent'] | email['decent'] | phone_number['decent'] | aadhaar['decent'] | pan['decent'], sensitivity['decent'])
rule15 = ctrl.Rule(username['good'] | password['good'] | email['good'] | phone_number['good'] | aadhaar['good'] | pan['good'], sensitivity['good'])
rule16 = ctrl.Rule(username['poor'] | password['poor'] | email['poor'] | phone_number['poor'] | aadhaar['poor'] | pan['poor'], sensitivity['poor'])
rule17 = ctrl.Rule(username['mediocre'] | password['mediocre'] | email['mediocre'] | phone_number['mediocre'] | aadhaar['mediocre'] | pan['mediocre'], sensitivity['mediocre'])
rule18 = ctrl.Rule(username['average'] | password['average'] | email['average'] | phone_number['average'] | aadhaar['average'] | pan['average'], sensitivity['average'])
rule19 = ctrl.Rule(username['decent'] | password['decent'] | email['decent'] | phone_number['decent'] | aadhaar['decent'] | pan['decent'], sensitivity['decent'])
rule20 = ctrl.Rule(username['good'] | password['good'] | email['good'] | phone_number['good'] | aadhaar['good'] | pan['good'], sensitivity['good'])
rule21 = ctrl.Rule(username['poor'] | password['poor'] | email['poor'] | phone_number['poor'] | aadhaar['poor'] | pan['poor'], sensitivity['poor'])
rule22 = ctrl.Rule(username['mediocre'] | password['mediocre'] | email['mediocre'] | phone_number['mediocre'] | aadhaar['mediocre'] | pan['mediocre'], sensitivity['mediocre'])
rule23 = ctrl.Rule(username['average'] | password['average'] | email['average'] | phone_number['average'] | aadhaar['average'] | pan['average'], sensitivity['average'])
rule24 = ctrl.Rule(username['decent'] | password['decent'] | email['decent'] | phone_number['decent'] | aadhaar['decent'] | pan['decent'], sensitivity['decent'])
rule25 = ctrl.Rule(username['good'] | password['good'] | email['good'] | phone_number['good'] | aadhaar['good'] | pan['good'], sensitivity['good'])
rule26 = ctrl.Rule(username['poor'] | password['poor'] | email['poor'] | phone_number['poor'] | aadhaar['poor'] | pan['poor'], sensitivity['poor'])
rule27 = ctrl.Rule(username['mediocre'] | password['mediocre'] | email['mediocre'] | phone_number['mediocre'] | aadhaar['mediocre'] | pan['mediocre'], sensitivity['mediocre'])
rule28 = ctrl.Rule(username['average'] | password['average'] | email['average'] | phone_number['average'] | aadhaar['average'] | pan['average'], sensitivity['average'])
rule29 = ctrl.Rule(username['decent'] | password['decent'] | email['decent'] | phone_number['decent'] | aadhaar['decent'] | pan['decent'], sensitivity['decent'])
rule30 = ctrl.Rule(username['good'] | password['good'] | email['good'] | phone_number['good'] | aadhaar['good'] | pan['good'], sensitivity['good'])
rule31 = ctrl.Rule(username['average'] | password['poor'] | email['poor'] | phone_number['poor'] | aadhaar['poor'] | pan['poor'], sensitivity['poor'])
# Create the control system
sensitivity_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9, rule10, rule11, rule12, rule13, rule14, rule15, rule16, rule17, rule18, rule19, rule20, rule21, rule22, rule23, rule24, rule25, rule26, rule27, rule28, rule29, rule30,rule31])

# Update the simulation
sensitivity_sim = ctrl.ControlSystemSimulation(sensitivity_ctrl)
# View the membership functions and rules (optional)
sensitivity.view(sim=sensitivity_sim)
# Out:
# c:\Users\LAKSHMI SRI LASYA\AppData\Local\Programs\Python\Python311\Lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import re
# Define the regular expressions for sensitive data fields
username_regex = re.compile(r'\busername\b')
password_regex = re.compile(r'\bpassword\b')
email_id_regex = re.compile(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b')
phone_number_regex = re.compile(r'\b\d{3}[-.\s]??\d{3}[-.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-.\s]??\d{4}|\d{3}[-.\s]??\d{4}\b')
aadhaar_regex = re.compile(r'\b\d{4}\s\d{4}\s\d{4}\b')  
pan_regex = re.compile(r'[A-Z]{5}\d{4}[A-Z]{1}') 
# Assign numbers to these fields
username_number = 5
password_number = 5
email_id_number = 5
phone_number_number = 5
aadhaar_number = 5
pan_number = 5  
# Get user input
user_input = input("Enter text: ")
# Initialize a dictionary to hold the fuzzy system input
fuzzy_input = {'username': 0, 'password': 0, 'email_id': 0, 'phone_number': 0, 'pan': 0, 'aadhaar': 0}
# Identify these fields in the user input and assign them their respective numbers
if username_regex.search(user_input):
    fuzzy_input['username'] = username_number
if password_regex.search(user_input):  
    fuzzy_input['password'] = password_number
if email_id_regex.search(user_input):
    fuzzy_input['email_id'] = email_id_number
if phone_number_regex.search(user_input):
    fuzzy_input['phone_number'] = phone_number_number
if pan_regex.search(user_input):
    fuzzy_input['pan'] = pan_number  
if aadhaar_regex.search(user_input):
    fuzzy_input['aadhaar'] = aadhaar_number

print("Fuzzy system input:", fuzzy_input)
# Out:
# Fuzzy system input: {'username': 0, 'password': 0, 'email_id': 0, 'phone_number': 0, 'pan': 0, 'aadhaar': 0}

# %%
# Create a new cell in the Jupyter Notebook

# Import the necessary modules if not already imported
import skfuzzy as fuzz
# Create a new instance of ControlSystemSimulation
sensitivity_sim = ctrl.ControlSystemSimulation(sensitivity_ctrl)
# Set the inputs of the simulation using the fuzzy_input dictionary
sensitivity_sim.input['username'] = fuzzy_input['username']
sensitivity_sim.input['password'] = fuzzy_input['password']
sensitivity_sim.input['email'] = fuzzy_input['email_id']
sensitivity_sim.input['phone_number'] = fuzzy_input['phone_number']    
sensitivity_sim.input['aadhaar'] = fuzzy_input['aadhaar']   
sensitivity_sim.input['pan'] = fuzzy_input['pan']   
# Compute the outputs of the simulation   
sensitivity_sim.compute()  
# Access the sensitivity rate
sensitivity_rate = sensitivity_sim.output['sensitivity']
# Access the sensitivity rate
sensitivity_rate = sensitivity_sim.output['sensitivity']
if sensitivity_rate > 6.7:
    classification = 'Highly Sensitive'
elif sensitivity_rate > 3.3:
    classification = 'Medium Sensitivity'
else:
    classification = 'Low Sensitivity'
print("Sensitivity Rate:", sensitivity_rate)
print("Classification:", classification)
# Out:
# Sensitivity Rate: 0.8974358974358974
# Classification: Low Sensitivity
